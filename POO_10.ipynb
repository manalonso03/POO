# %% [markdown]
# # Simulaciones Monte-Carlo

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
from pandas_datareader import data as pdr # Esta función descarga datos a partir de fuentes distintas distintas a yfinance

# %%
import yfinance as yf
yf.pdr_override()

# %%
apple = pdr.get_data_yahoo("AAPL", start = "2022-10-24", end="2022-12-23")
apple
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-10-24  147.190002  150.229996  146.000000  149.449997  148.568634
# 2022-10-25  150.089996  152.490005  149.360001  152.339996  151.441605
# 2022-10-26  150.960007  151.990005  148.039993  149.350006  148.469238
# 2022-10-27  148.070007  149.050003  144.130005  144.800003  143.946060
# 2022-10-28  148.199997  157.500000  147.820007  155.740005  154.821548
# 2022-10-31  153.160004  154.240005  151.919998  153.339996  152.435684
# 2022-11-01  155.080002  155.449997  149.130005  150.649994  149.761551
# 2022-11-02  148.949997  152.169998  145.000000  145.029999  144.174698
# 2022-11-03  142.059998  142.800003  138.750000  138.880005  138.060974
# 2022-11-04  142.089996  142.669998  134.380005  138.380005  137.792130
# 2022-11-07  137.110001  139.149994  135.669998  138.919998  138.329819
# ...

# %% [markdown]
# ## Vamos a calcular el crecimiento anual compuesto sobre las fechas dadas.

# %%
apple["Adj Close"][-1:] # El argumento [-1] regresa el ultimo valor de la serie
# Out:
# Date
# 2022-12-22    131.668243
# Name: Adj Close, dtype: float64

# %%
crecimiento_total = apple["Adj Close"][1]/apple["Adj Close"][-1]
crecimiento_total
# Out:
# 1.150175628490406

# %% [markdown]
# Anualizar porcentajes:

# %%
tiempo_transcurrido = (apple.index[-1]-apple.index[0]).days
tiempo_transcurrido
# Out:
# 59

# %%
len(list(apple.index))
# Out:
# 43

# %%
crecimiento_compuesto = crecimiento_total**(43)-1
crecimiento_compuesto
# Out:
# 409.0708702642962

# %%
# Vamos a calcular la volatilidad de los rendimientos
volatilidad = apple["Adj Close"].pct_change().std()
volatilidad
# Out:
# 0.027407151440380063

# %%
volatilidad_total = volatilidad*math.sqrt(252) # 252**0.5
volatilidad_total
# Out:
# 0.43507504113558804

# %%
# Vamos a generar porcentajes de rendimiento diario
rendimientos_diarios = np.random.normal()
