# %% [markdown]
# # Puntos en las ultimas 10 temporadas de la liga

# %%
LaLiga= { "Atletico": [91, 93, 87, 94, 83, 77, 88, 90, 96, 100],"Barcelona": [90, 91, 86, 90, 81, 79, 89, 92, 91, 77],
         "Madrid": [80, 91, 81, 90, 87, 78, 81, 97, 90, 101], "Valencia": [72, 82, 70, 63, 72, 81, 85, 57, 61, 80],
          "Villareal": [73, 75, 74, 62, 80, 71, 80, 71, 62, 70], "Sevilla": [90, 90, 81, 91, 80, 71, 80, 92, 91, 93],
          "Betis": [73, 60, 63, 74, 80, 77, 80, 76, 66, 70], "Alaves": [51, 63, 47, 44, 53, 57, 38, 40, 46, 50],
          "Real Sociedad": [71, 73, 81, 64, 63, 57, 68, 80, 76, 74], "Espanyol": [31, 43, 57, 64, 73, 47, 48, 50, 46, 30]}

# %%
print (LaLiga)
# Out:
# {'Atletico': [91, 93, 87, 94, 83, 77, 88, 90, 96, 100], 'Barcelona': [90, 91, 86, 90, 81, 79, 89, 92, 91, 77], 'Madrid': [80, 91, 81, 90, 87, 78, 81, 97, 90, 101], 'Valencia': [72, 82, 70, 63, 72, 81, 85, 57, 61, 80], 'Villareal': [73, 75, 74, 62, 80, 71, 80, 71, 62, 70], 'Sevilla': [90, 90, 81, 91, 80, 71, 80, 92, 91, 93], 'Betis': [73, 60, 63, 74, 80, 77, 80, 76, 66, 70], 'Alaves': [51, 63, 47, 44, 53, 57, 38, 40, 46, 50], 'Real Sociedad': [71, 73, 81, 64, 63, 57, 68, 80, 76, 74], 'Espanyol': [31, 43, 57, 64, 73, 47, 48, 50, 46, 30]}

# %%
import pandas as pd

# %%
Puntos = pd.DataFrame(LaLiga)

# %%
Puntos
# Out:
#    Atletico  Barcelona  Madrid  Valencia  Villareal  Sevilla  Betis  Alaves  \
# 0        91         90      80        72         73       90     73      51
# 1        93         91      91        82         75       90     60      63
# 2        87         86      81        70         74       81     63      47
# 3        94         90      90        63         62       91     74      44
# 4        83         81      87        72         80       80     80      53
# 5        77         79      78        81         71       71     77      57
# 6        88         89      81        85         80       80     80      38
# 7        90         92      97        57         71       92     76      40
# 8        96         91      90        61         62       91     66      46
# 9       100         77     101        80         70       93     70      50
#
#    Real Sociedad  Espanyol
# 0             71        31
# 1             73        43
# 2             81        57
# ...
