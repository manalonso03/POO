# %% [markdown]
# ## Tarea 1. Primera parte.

# %% [markdown]
# 1.   Genera una lista que consista de $20$ números que estén en el intervalo $[-1,1]$. Llámala `Lista_1`.
# 2.   Genera una lista que consista de $20$ números que sean enteros en el intervalo $[1500, 3000]$. Llámala `Lista_2`.
# 3. Crea un diccionario cuyas llaves sean "**CapSmall**" y "**CapLarge**" y sus valores sean la `Lista_1` y `Lista_2`, respectivamente.
# 4. Crea un `DataFrame` a partir del diccionario del punto anterior. Llámalo df.
# 5. Reindexa los índices poniendo Año 1$,...,$ Año 20.
# 6. Realiza una explicación de la estadística descriptiva de tu `DataFrame`.
# 7. ¿Cuál es el valor mínimo de la columna "**CapSmall**"?
# 8. ¿Cuál es "**CapLarge**" promedio del año 10 al año 20.
# 9. Realiza una gráfica de Año contra "**CapLarge**".
# 10. Muestra el `DataFrame` que obtienes si tomas aquellos valores de "**CapLarge**" mayores a $2000$. ¿Cuál es la dimensión (shape) de tu nueva base de datos?

# %%
import numpy as np
import pandas as pd

# %%
# Ejercicio 1
Lista_1 = np. random.uniform(low=-1,high=1, size=20)
Lista_1
# Out:
# array([ 0.50880709,  0.50458163, -0.01604336,  0.24010347,  0.34041456,
#         0.99432272,  0.60163148,  0.4501676 , -0.99368354,  0.94001375,
#         0.06639462,  0.12644099, -0.09364665, -0.33458962,  0.17326139,
#         0.12412847,  0.55933974, -0.17974481, -0.25607139,  0.71929709])

# %%
# Ejercicio 2
Lista_2= np.random.randint(low=1500,high=3000,size=20)
Lista_2
# Out:
# array([2390, 2566, 1939, 1945, 1680, 2874, 2598, 1966, 2171, 2271, 1811,
#        1822, 1528, 2053, 2130, 2992, 1892, 2204, 1568, 2966])

# %%
#Ejercicio 3
Diccionario_1={"CapSmall":Lista_1,"CapLarge":Lista_2}
Diccionario_1
# Out:
# {'CapSmall': array([ 0.50880709,  0.50458163, -0.01604336,  0.24010347,  0.34041456,
#          0.99432272,  0.60163148,  0.4501676 , -0.99368354,  0.94001375,
#          0.06639462,  0.12644099, -0.09364665, -0.33458962,  0.17326139,
#          0.12412847,  0.55933974, -0.17974481, -0.25607139,  0.71929709]),
#  'CapLarge': array([2390, 2566, 1939, 1945, 1680, 2874, 2598, 1966, 2171, 2271, 1811,
#         1822, 1528, 2053, 2130, 2992, 1892, 2204, 1568, 2966])}

# %%
# Ejercicio 4 y 5
df=pd.DataFrame(Diccionario_1, index=["Año 1", "Año 2", "Año 3", "Año 4", "Año 5", "Año 6", "Año 7", "Año 8", "Año 9", "Año 10", "Año 11", "Año 12", "Año 13","Año 14", "Año 15", "Año 16", "Año 17", "Año 18", "Año 19", "Año 20"])
df
# Out:
#         CapSmall  CapLarge
# Año 1   0.508807      2390
# Año 2   0.504582      2566
# Año 3  -0.016043      1939
# Año 4   0.240103      1945
# Año 5   0.340415      1680
# Año 6   0.994323      2874
# Año 7   0.601631      2598
# Año 8   0.450168      1966
# Año 9  -0.993684      2171
# Año 10  0.940014      2271
# Año 11  0.066395      1811
# Año 12  0.126441      1822
# Año 13 -0.093647      1528
# Año 14 -0.334590      2053
# Año 15  0.173261      2130
# Año 16  0.124128      2992
# Año 17  0.559340      1892
# Año 18 -0.179745      2204
# Año 19 -0.256071      1568
# Año 20  0.719297      2966

# %%
# Ejercicio 6
df.describe()
# Out:
#         CapSmall     CapLarge
# count  20.000000    20.000000
# mean    0.223756  2168.300000
# std     0.471556   441.733678
# min    -0.993684  1528.000000
# 25%    -0.035444  1874.500000
# 50%     0.206682  2091.500000
# 75%     0.521440  2434.000000
# max     0.994323  2992.000000

# %%
#Ejercicio 7
min(Lista_1)
# Out:
# -0.9936835365037897

# %%
#Ejercicio 8
Promedio_CapLarge= df.iloc[10:20]
Promedio_CapLarge= Promedio_CapLarge.drop(columns="CapSmall")
Promedio_CapLarge
# Out:
#         CapLarge
# Año 11      1811
# Año 12      1822
# Año 13      1528
# Año 14      2053
# Año 15      2130
# Año 16      2992
# Año 17      1892
# Año 18      2204
# Año 19      1568
# Año 20      2966

# %%
Promedio_CapLarge.mean()
# Out:
# CapLarge    2096.6
# dtype: float64

# %%
import pandas as pd

# %%
#Ejercicio 9

df_CapSmall=df.drop(columns="CapSmall")
df_CapSmall
# Out:
#         CapLarge
# Año 1       2390
# Año 2       2566
# Año 3       1939
# Año 4       1945
# Año 5       1680
# Año 6       2874
# Año 7       2598
# Año 8       1966
# Año 9       2171
# Año 10      2271
# Año 11      1811
# Año 12      1822
# Año 13      1528
# Año 14      2053
# Año 15      2130
# Año 16      2992
# Año 17      1892
# Año 18      2204
# Año 19      1568
# Año 20      2966

# %%
#Ejercicio 10
mayores = df["CapLarge"] > 2000
ultima_df = df[mayores]
ultima_df
# Out:
#         CapSmall  CapLarge
# Año 1   0.508807      2390
# Año 2   0.504582      2566
# Año 6   0.994323      2874
# Año 7   0.601631      2598
# Año 9  -0.993684      2171
# Año 10  0.940014      2271
# Año 14 -0.334590      2053
# Año 15  0.173261      2130
# Año 16  0.124128      2992
# Año 18 -0.179745      2204
# Año 20  0.719297      2966
